# %% [markdown]
# <a href="https://colab.research.google.com/github/DressaLuc/spotify-trends-analysis/blob/main/spotify_trends_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 | **Primeiros passos em Python**
#
# Hoje vamos:
# - Revisar alguns conceitos iniciais
# - Explorar dados reais usando Python
# - Aprender os primeiros comandos com **Pandas** e **Matplotlib**
# - Criar gráficos para responder perguntas
#
# ---

# %% [markdown]
# ## Conceitos básicos
#
# <img src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExNHBwNDhvMDRoNDlvb2pkYnhtdGt4YXhqaWw1Y2Ixa200M2gxZDcxNiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/109fP7pua6Osgw/giphy.gif" width="300">

# %% [markdown]
# ### Tipos de dados
# `int`, `float`, `str`, `bool`

# %%
idade = 32
nome = "Malu"
tem_acesso = True
nota = 8.5

# %%
print(type(idade), type(nome), type(tem_acesso), type(nota))
# Out:
# <class 'int'> <class 'str'> <class 'bool'> <class 'float'>

# %%
idade = "32"
type(idade)
# Out:
# str

# %%
idade_int = int(idade)
type(idade_int)
# Out:
# int

# %%
valor = "10.5"
valor_float = float(valor) # convertendo de str para float
valor_int = int(float(valor))

print(f'Exemplo float: {type(valor_float)}:{valor_float}')
print(f'Exemplo int: {type(valor_int)}:{valor_int}')
# Out:
# Exemplo float: <class 'float'>:10.5
# Exemplo int: <class 'int'>:10

# %% [markdown]
# ### Listas

# %%
nome = ["Ana", "Malu", "Cristiane", "Paula", "Carol", "Julia", "Maria"]
print(type(nome))
# Out:
# <class 'list'>

# %%
print(nome[0]) #primeiro elemento
print(nome[-1]) #ultimo elemento
print(nome[2:4]) #meiuca da lista

nome_exemplo = nome[2:4]
# Out:
# Ana
# Maria
# ['Cristiane', 'Paula']

# %%
nome.append("Amanda") #adiciona um novo item
print(nome)
# Out:
# ['Ana', 'Malu', 'Cristiane', 'Paula', 'Carol', 'Julia', 'Maria', 'Amanda']

# %%
nome.remove("Malu") #adiciona um novo item
print(nome)
# Out:
# ['Ana', 'Cristiane', 'Paula', 'Carol', 'Julia', 'Maria', 'Amanda']

# %%
print("Ana" in nome)
# Out:
# True

# %% [markdown]
# ### Estruturas de decisão
# `if`, `elif` e `else`

# %%
nota = 5

if nota >= 7:
  print('Aprovada')
else:
  print('Reprovada')
# Out:
# Reprovada

# %%
nota = 3

if nota >= 9:
  print('Excelente')
elif nota >= 7:
  print("Bom desemepenho")
elif nota >= 5:
  print('Em recuperação')
else:
  print('Reprovada')
# Out:
# Reprovada

# %% [markdown]
# ### Loops
# `for` e `while`

# %%
for i in range(3):
  print(f'Rodando o loop {i + 1}')
# Out:
# Rodando o loop 1
# Rodando o loop 2
# Rodando o loop 3

# %%
contador = 1

while contador <= 5:
  print(f'Contando... {contador}')
  contador += 1 # incrementando o valor do contador

print('Fim do loop')
# Out:
# Contando... 1
# Contando... 2
# Contando... 3
# Contando... 4
# Contando... 5
# Fim do loop

# %% [markdown]
# ## 🎧 Explorando dados do Spotify
#
# <img src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExaWJtNjFxcmJ6YXk4eDAyMXVyc3o3cGF2NGF6czhkaXl1anAzNzU0ciZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/bgDd8eRNi6NK8/giphy.gif" width="300">
#
#
# Aqui, vamos explorar dados extraídos da conta de um usuário do Spotify para entender um pouco do seu perfil e gosto musical. Trabalharemos com dois datasets:
# 1. **playlists_tracks**: contém a listagem de todas as suas playlists públicas e as músicas contidas nelas
# 2. **genres_artists**: contém a listagem de artistas presentes nas playlists e seus gêneros

# %% [markdown]
# ### Leitura e visão geral dos dados

# %%
import pandas as pd

# %%
playlists_tracks = pd.read_csv('./playlists_tracks')
genres_artists = pd.read_csv('./genres_artists')

# %%
type(playlists_tracks)
# Out:
# pandas.core.frame.DataFrame

# %%
playlists_tracks.shape
# Out:
# (8661, 10)

# %%
genres_artists.shape
# Out:
# (934, 3)

# %%
playlists_tracks.head(2)
# Out:
#    Unnamed: 0             playlist_id           playlist_name  \
# 0           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 1           1  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
#
#                  track_id           track_name              artist_names  \
# 0  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 1  2DlHlPMa4M17kufBvI2lEN           Chop Suey!          System Of A Down
#
#                                           album_name album_release_date  \
# 0  Rage Against The Machine - XX (20th Anniversar...               1992
# 1                                           Toxicity         2001-09-04
#
#    popularity  duration_ms
# 0          79       313573
# 1          85       210240

# %%
genres_artists.head(3)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
# 2           2                 Metallica
#
#                                               genres
# 0   rap metal, rap rock, alternative metal, nu metal
# 1  nu metal, metal, alternative metal, rap metal,...
# 2  metal, thrash metal, rock, heavy metal, hard rock

# %%
playlists_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8661 entries, 0 to 8660
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          8661 non-null   int64
#  1   playlist_id         8661 non-null   object
#  2   playlist_name       8661 non-null   object
#  3   track_id            8661 non-null   object
#  4   track_name          8659 non-null   object
#  5   artist_names        8659 non-null   object
#  6   album_name          8659 non-null   object
#  7   album_release_date  8661 non-null   object
#  8   popularity          8661 non-null   int64
#  9   duration_ms         8661 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 676.8+ KB

# %%
playlists_tracks["playlist_name"].value_counts().head(5)
# Out:
# playlist_name
# Caminhando sem padrão nenhum         311
# Rockzim pra cantar junto             300
# cantando feat. rebolando             274
# tudo misturado curtindo uma chuva    261
# Radio em '00                         241
# Name: count, dtype: int64

# %% [markdown]
# ### Limpeza e transformações
#
# Antes de analisarmos as playlists e os gêneros, vamos preparar nossos dados:
# 1. Extrair apenas o **ano** da data de lançamento dos álbuns
# 2. Remover músicas com **nome ausente**
# 3. Transformar a tabela de gêneros para que cada **gênero tenha uma linha própria**

# %% [markdown]
# 1. Extrair o ano

# %%
playlists_tracks['album_release_date_ajustado'] = pd.to_datetime(playlists_tracks['album_release_date'], errors="coerce")

# %%
playlists_tracks.columns
# Out:
# Index(['Unnamed: 0', 'playlist_id', 'playlist_name', 'track_id', 'track_name',
#        'artist_names', 'album_name', 'album_release_date', 'popularity',
#        'duration_ms', 'album_release_date_ajustado'],
#       dtype='object')

# %%
playlists_tracks['album_release_year'] = playlists_tracks["album_release_date_ajustado"].dt.year
playlists_tracks.head(3)
# Out:
#    Unnamed: 0             playlist_id           playlist_name  \
# 0           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 1           1  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 2           2  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
#
#                  track_id                       track_name  \
# 0  59WN2psjkt1tyaxjspN8fp              Killing In The Name
# 1  2DlHlPMa4M17kufBvI2lEN                       Chop Suey!
# 2  3DwQ7AH3xGD9h65ezslm6q  Enter Sandman - Remastered 2021
#
#                artist_names  \
# 0  Rage Against The Machine
# 1          System Of A Down
# 2                 Metallica
#
#                                           album_name  album_release_date  \
# 0  Rage Against The Machine - XX (20th Anniversar...              1992.0
# 1                                           Toxicity                 NaN
# 2              Metallica (Remastered Deluxe Box Set)                 NaN
#
#    popularity  duration_ms album_release_date_ajustado
# 0          79       313573                  1992-01-01
# 1          85       210240                         NaT
# 2          83       331560                         NaT

# %% [markdown]
# 2. Excluir linhas com track_name ausente

# %%
playlists_tracks.shape
# Out:
# (8661, 11)

# %%
playlists_tracks_clean = playlists_tracks.dropna(subset=['track_name'])
playlists_tracks_clean.shape
# Out:
# (8659, 10)

# %% [markdown]
# 3. Explodir os gêneros (1 linha por artista e gênero)

# %%
genres_artists.head(3)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
# 2           2                 Metallica
#
#                                               genres
# 0   rap metal, rap rock, alternative metal, nu metal
# 1  nu metal, metal, alternative metal, rap metal,...
# 2  metal, thrash metal, rock, heavy metal, hard rock

# %%
genres_artists['lista'] = genres_artists['genres'].fillna("").str.split(",")
genres_artists.head(2)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
#
#                                               genres  \
# 0   rap metal, rap rock, alternative metal, nu metal
# 1  nu metal, metal, alternative metal, rap metal,...
#
#                                                lista
# 0  [rap metal,  rap rock,  alternative metal,  nu...
# 1  [nu metal,  metal,  alternative metal,  rap me...

# %%
genres_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   934 non-null    int64
#  1   artist_name  934 non-null    object
#  2   genres       660 non-null    object
#  3   lista        934 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 29.3+ KB

# %%
genres_exploded = genres_artists.explode("lista")
genres_exploded.head(10)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
# 1           1          System Of A Down
# 1           1          System Of A Down
# 1           1          System Of A Down
# 1           1          System Of A Down
# 2           2                 Metallica
#
#                                               genres               lista
# 0   rap metal, rap rock, alternative metal, nu metal           rap metal
# 0   rap metal, rap rock, alternative metal, nu metal            rap rock
# 0   rap metal, rap rock, alternative metal, nu metal   alternative metal
# 0   rap metal, rap rock, alternative metal, nu metal            nu metal
# 1  nu metal, metal, alternative metal, rap metal,...            nu metal
# 1  nu metal, metal, alternative metal, rap metal,...               metal
# 1  nu metal, metal, alternative metal, rap metal,...   alternative metal
# 1  nu metal, metal, alternative metal, rap metal,...           rap metal
# 1  nu metal, metal, alternative metal, rap metal,...                rock
# 2  metal, thrash metal, rock, heavy metal, hard rock               metal

# %%
genres_exploded.shape
# Out:
# (1789, 4)

# %%
genres_exploded = genres_exploded.rename(columns={'lista': 'genero'})
genres_exploded.head(2)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
#
#                                              genres     genero
# 0  rap metal, rap rock, alternative metal, nu metal  rap metal
# 0  rap metal, rap rock, alternative metal, nu metal   rap rock

# %%
'   string exemplo   '.strip()
# Out:
# 'string exemplo'

# %%
genres_exploded['genero'] = genres_exploded['genero'].str.strip()

# %%
genres_exploded = genres_exploded[genres_exploded['genero'] != '']
genres_exploded.shape
# Out:
# (1515, 4)

# %%
genres_exploded.drop(columns=['genres', 'Unnamed: 0'], inplace=True)
genres_exploded.head(5)
# Out:
#                 artist_name             genero
# 0  Rage Against The Machine          rap metal
# 0  Rage Against The Machine           rap rock
# 0  Rage Against The Machine  alternative metal
# 0  Rage Against The Machine           nu metal
# 1          System Of A Down           nu metal

# %% [markdown]
# ## Visualização com Matplotlib
#
# <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExazlycDZvOXZzbXN1Z2djZzZ3cnU0M3FkeXdnbzJxMGdjbmpsZGVseSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/iRIf7MAdvOIbdxK4rR/giphy.gif" width="300">
#
# Agora que os dados estão limpos, vamos responder algumas perguntas com gráficos.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Quais playlists têm mais músicas?

# %%
playlist_counts = playlists_tracks_clean['playlist_name'].value_counts().head(10)
playlist_countsb
# Out:
# playlist_name
# Caminhando sem padrão nenhum         311
# Rockzim pra cantar junto             300
# cantando feat. rebolando             274
# tudo misturado curtindo uma chuva    261
# Radio em '00                         241
# VOLTA JUVENTUDE                      239
# Black power                          231
# jovem indie                          219
# Top indie                            215
# Só ~good vibe~                       210
# Name: count, dtype: int64

# %%
playlist_counts.plot(kind="barh", figsize=(8,5))

plt.title('Top 10 playlists com mais músicas')
plt.xlabel("Quantidade de músicas")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Como evolui a quantidade de músicas lançadas por ano nas playlists?

# %%
plt.style.use('seaborn-v0_8')

# %%
songs_per_year = (
    playlists_tracks_clean['album_release_date']
    .value_counts()
    .sort_index()
)

songs_per_year
# Out:
# album_release_date
# 1958.0     1
# 1960.0     4
# 1964.0     3
# 1966.0     1
# 1967.0     7
# 1968.0    14
# 1969.0     5
# 1970.0    25
# 1971.0     5
# 1972.0    22
# 1973.0    15
# 1974.0     7
# 1975.0    19
# 1976.0     6
# 1977.0     9
# 1978.0     8
# 1979.0    10
# 1980.0     5
# 1981.0     5
# 1982.0    12
# 1983.0     2
# 1984.0    11
# 1985.0     5
# 1986.0     3
# 1987.0     2
# 1988.0     8
# 1989.0     2
# 1990.0     1
# 1991.0     3
# 1992.0    18
# 1993.0     2
# 1994.0     2
# 1995.0    34
# 1996.0     5
# 1997.0     5
# 1999.0    21
# 2000.0    25
# 2001.0    29
# 2002.0    27
# 2003.0    14
# 2004.0    42
# 2005.0     3
# 2006.0    13
# 2007.0    18
# 2008.0    11
# 2009.0    36
# 2010.0    12
# 2011.0    20
# 2012.0     3
# 2013.0    41
# 2015.0     1
# 2016.0    10
# 2019.0    17
# Name: count, dtype: int64

# %%
songs_per_year.plot(kind='line', marker="o", figsize=(8,4))

plt.title('Quantidade de músicas lançadas por ano', loc='left')
plt.xlabel("")
plt.ylabel("Número de músicas")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Quais são os artistas com maior popularidade média?

# %%
popularidade_media_artistas = playlists_tracks_clean.groupby('artist_names')['popularity'].mean().sort_values(ascending=False)
print(popularidade_media_artistas.head(10))
# Out:
# artist_names
# The Neighbourhood                 91.000000
# Gorillaz, De La Soul              90.000000
# Fleetwood Mac                     89.000000
# The Weeknd, Daft Punk             89.000000
# Kendrick Lamar, SZA               89.000000
# Tyler, The Creator, Kali Uchis    89.000000
# Bad Bunny                         88.333333
# sombr                             88.000000
# The Chainsmokers, Halsey          86.000000
# a-ha                              86.000000
# Name: popularity, dtype: float64

# %%
artists_counts.plot(kind="barh", figsize=(8,5))
plt.title("Top 10 artistas mais tocados")
plt.xlabel("Quantidade de vezes que tocou")
plt.ylabel("")
plt.show()

# %%
popularidade_artista = playlists_tracks_clean.groupby('artist_names')["popularity"].mean().reset_index().sort_values("popularity", ascending=False)
print(popularidade_artista.head(10))
# Out:
#                         artist_names  popularity
# 1257               The Neighbourhood   91.000000
# 512             Gorillaz, De La Soul   90.000000
# 452                    Fleetwood Mac   89.000000
# 1289           The Weeknd, Daft Punk   89.000000
# 712              Kendrick Lamar, SZA   89.000000
# 1341  Tyler, The Creator, Kali Uchis   89.000000
# 92                         Bad Bunny   88.333333
# 1413                           sombr   88.000000
# 1231        The Chainsmokers, Halsey   86.000000
# 1404                            a-ha   86.000000

# %% [markdown]
# ### Quais são os artistas mais frequentes nas playlists?

# %%
# 1. Agrupa pelo nome do artista
# 2. Usa .size() para contar o número de linhas (músicas) em cada grupo
# 3. Transforma a Série resultante em DataFrame e nomeia a nova coluna como 'frequencia'
# 4. Ordena do mais frequente para o menos frequente
artistas_frequentes = playlists_tracks_clean.groupby('artist_names').size().reset_index(name='frequencia').sort_values('frequencia', ascending=False)
print(artistas_frequentes.head(10))
# Out:
#                artist_names  frequencia
# 982                   Oasis         160
# 988             Olivia Dean         159
# 666                  Jungle         143
# 61           Arctic Monkeys         138
# 135                 Beyoncé         131
# 1073  Red Hot Chili Peppers         124
# 1275            The Strokes         119
# 199       Cage The Elephant         103
# 723           Kings of Leon         100
# 566                 Incubus          84

# %% [markdown]
# ### Quais gêneros são mais frequentes entre os artistas das playlists?

# %%
# 1. Agrupa pelo nome do artista
# 2. Usa .size() para contar o número de linhas (músicas) em cada grupo
# 3. Transforma a Série resultante em DataFrame e nomeia a nova coluna como 'frequencia'
# 4. Ordena do mais frequente para o menos frequente


generos_frequentes = genres_exploded.groupby('genero').size().reset_index(name='frequencia').sort_values('frequencia', ascending=False)
print(generos_frequentes.head(10))
# Out:
#              genero  frequencia
# 134             mpb         111
# 143        nova mpb          80
# 184           samba          67
# 38   brazilian rock          51
# 37    brazilian pop          43
# 149          pagode          38
# 177            rock          30
# 20              axé          28
# 74            forró          26
# 32       bossa nova          25

# %% [markdown]
# ### Qual é a duração média das músicas por playlist?

# %%
mean_hit = df['duration_ms'].mean()
print(f'A duração perfeita de um hit foi de {round(mean_hit,2)} segundos')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1357592215.py in <cell line: 0>()
# ----> 1 mean_hit = df['duration_ms'].mean()
#       2 print(f'A duração perfeita de um hit foi de {round(mean_hit,2)} segundos')
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Exercício: Existe relação entre o ano de lançamento e a duração média das músicas?

# %%
dec_3 = playlists_tracks_clean[playlists_tracks_clean["album_release_date_ajustado"].dt.year.isin([2000,2010,2020])].sort_values("popularity", ascending = False)
dec_3[["album_release_date_ajustado", "duration_ms"]].groupby("album_release_date_ajustado").agg(["mean"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2643028956.py in <cell line: 0>()
# ----> 1 dec_3 = playlists_tracks_clean[playlists_tracks_clean["album_release_date_ajustado"].dt.year.isin([2000,2010,2020])].sort_values("popularity", ascending = False)
#       2 dec_3[["album_release_date_ajustado", "duration_ms"]].groupby("album_release_date_ajustado").agg(["mean"])
#
# NameError: name 'playlists_tracks_clean' is not defined

# %% [markdown]
# ### Exercício: Quão diversa em gêneros é cada playlist?
# Em outras palavras, quais playlists têm mais gêneros distintos entre os artistas que aparecem nelas?

# %%
df = playlists_tracks.merge(
    genres_exploded, left_on='artist_names', right_on='artist_name', how='left'
)

df.head(5)
# Out:
#    Unnamed: 0             playlist_id           playlist_name  \
# 0           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 1           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 2           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 3           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 4           1  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
#
#                  track_id           track_name              artist_names  \
# 0  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 1  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 2  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 3  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 4  2DlHlPMa4M17kufBvI2lEN           Chop Suey!          System Of A Down
#
#                                           album_name album_release_date  \
# 0  Rage Against The Machine - XX (20th Anniversar...               1992
# 1  Rage Against The Machine - XX (20th Anniversar...               1992
# 2  Rage Against The Machine - XX (20th Anniversar...               1992
# 3  Rage Against The Machine - XX (20th Anniversar...               1992
# 4                                           Toxicity         2001-09-04
#
#    popularity  duration_ms               artist_name             genero
# 0          79       313573  Rage Against The Machine          rap metal
# 1          79       313573  Rage Against The Machine           rap rock
# 2          79       313573  Rage Against The Machine  alternative metal
# 3          79       313573  Rage Against The Machine           nu metal
# 4          85       210240          System Of A Down           nu metal

# %%
generos_playlists = (
    df.groupby('playlist_name')['genero']
    .nunique(dropna=True)
    .sort_values(ascending=False)
    .head(5)
    .sort_values()
)

generos_playlists.head()
# Out:
# playlist_name
# Bom dia minha esquerdista       57
# Os classicão tudo               58
# Aquela jantinha                 62
# Toda zoë kravitz energy         79
# Caminhando sem padrão nenhum    81
# Name: genero, dtype: int64

# %%
generos_playlists.plot(kind="barh", figsize=(4,3))

plt.title('Playlists mais diversas')
plt.xlabel("Quantidade de gêneros")
plt.ylabel("")
plt.show()

# %% [markdown]
# ---
#
# <img src="https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExMmxwajYzcWh3NmRhNjN0N2plMDV5ZGdrcHQ0ZnlqeW55bTd6NjdnYSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/lD76yTC5zxZPG/giphy.gif" width="300">
